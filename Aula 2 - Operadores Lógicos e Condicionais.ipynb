# %% [markdown]
# # Aula  - Operadores Lógicos e Estruturas Condicionais
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Operadores lógicos;
# - 2) Estruturas condicionais;
#
# _______
#
# ### Objetivos
#
# Apresentar aos alunos os operadores lógicos de comparação e de conjunção, declarando a importância das operações lógicas nas estruturas condicionais e de repetição, que são apresentadas a seguir; Apresentar o conceito, uso e importâncias das estruturas condicionais em Python.
#
# ### Habilidades a serem desenvolvidas
#
# Ao final da aula o aluno deve:
#
# - Saber o conceito de operações lógicas e o seu resultado (True/False);
# - Saber interpretar e utilizar os operadores de comparação;
# - Saber interpretar e uitlizar os operadores de conjunção;
# - Saber formular expressões lógicas;

# %% [markdown]
# ____

# %% [markdown]
# ## 1) Operadores lógicos
#
# Em muitos problemas de programação, há necessidade de se fazer **comparações** entre variáveis.
#
# Por exemplo:
#
# - checar se um número é maior que outro;
# - checar se uma variável é igual a outra;
# - checar se há números diferentes; etc.
#
# Para fazer essas comparações, utilizamos os **operadores lógicos de comparação**. Em Python, há 6 desses operadores:
#
# - Maior que: >
# - Maior ou igual: >=
# - Menor que: <
# - Menor ou igual: <=
# - Igual: ==
# - Diferente: !=
#
# O resultado de uma comparação sempre vai ser um booleano, isto é, **True** ou **False**!
#
# Dica: sempre leia as comparações como uma **pergunta**
#
# - Ex: "numero < 100", leia: "o valor na variável numero é menor que 100?"
#
# Os operadores de comparação são destacados em **roxo** no Jupyter

# %%
100 > 100
# Out:
# False

# %%
100 < 10
# Out:
# False

# %%
100 <= 100
# Out:
# True

# %%
10 == 10
# Out:
# True

# %% [markdown]
# A comparação pode ser feita entre duas variáveis, também:

# %%
valorA = 100
valorB = 100
valorA < valorB
# Out:
# False

# %% [markdown]
# Python aceita multiplar comparações de ordem na mesma expressão:

# %%
n = 8
10 < n <= 1000
# Out:
# False

# %%
7 < n <= 1000 <= 999
# Out:
# False

# %% [markdown]
# Podemos também comparar strings!

# %%
"olá mundo" == "olá mundo"
# Out:
# True

# %%
"olá mundo" == "ola mundo"
# Out:
# False

# %% [markdown]
# Os operadores >, >=, <, <= atuam comparando **ordem de acordo com a tabela ascII** quando aplicados a strings.

# %%
"abacaxi" < "Banana" 
#a > B because uppercase characters comes before lowercase character in ascII table
# Out:
# False

# %%
"abacaxi" < "banana"
#a < b because lowercase a comes before lowercase b in ascII table
# Out:
# True

# %% [markdown]
# Podemos fazer comparação entre **tipos numéricos** diferentes (int e float):

# %%
valorA = 3
valorB = -3.14

valorA < valorB
# Out:
# False

# %%
valorA = 3
valorB = 3.14

valorA < valorB
# Out:
# True

# %% [markdown]
# Mas comparações entre string e tipos numéricos são possíveis **apenas para == e !=**:

# %%
"1" == 1 #dúvida: nesse caso o python compara os tipos?
# Out:
# False

# %%
int("1") == 1
# Out:
# True

# %%
"1" == str(1)
# Out:
# True

# %%
"2" != str(1)
# Out:
# True

# %% [markdown]
# Pode-se também comparar tipos

# %%
type(1) == int
# Out:
# True

# %%
type(1) == float
# Out:
# False

# %%
type(1.0) == int
# Out:
# False

# %%
type(1.0) == float
# Out:
# True

# %% [markdown]
# ___

# %% [markdown]
# Além dos operadores lógicos de comparação, também temos os **operadores lógicos de conjunção**, que são utilizados pra fazer uma **combinação** entre comparações.
#
# Os operadores de conjunção são: **and** e **or**, e eles seguem a seguinte regra:
#
# - **and** só é True se **ambas** as comparações forem True:
#     - False and True resulta em "False"
#     - False and False resulta em "False"
#     - True and True resulta em "True"
# - **or** é True se **pelo menos uma** das comparações for True:
#     - False or True resulta em "True"
#     - True or True resulta em "True"
#     - False or False resulta em "False"
#
# Os operadores de conjunção são destacados em **verde escuro** no Jupyter

# %%
print("Operador and:")
print(False and False)
print(True and False)
print(False and True)
print(True and True)
# Out:
# Operador and:
# False
# False
# False
# True

# %%
print("Logic inversion of 'and' statments:")
print(not(False and False) == (not(False) or not(False)))
print(not(True and False) == (not(True) or not(False)))
print(not(False and True) == (not(False) or not(True)))
print(not(True and True) == (not(True) or not(True)))
# Out:
# Logic inversion of 'and' statments:
# True
# True
# True
# True

# %%
10 < 50 and 5 == 5
# True and True
# Out:
# True

# %%
print("Operador or:")
print(False or False)
print(False or True)
print(True or False)
print(True or True)
# Out:
# Operador or:
# False
# True
# True
# True

# %%
print("Logic inversion of 'or' statments:")
print(not(False or False) == (not(False) and not(False)))
print(not(True or False) == (not(True) and not(False)))
print(not(False or True) == (not(False) and not(True)))
print(not(True or True) == (not(True) and not(True)))
# Out:
# Logic inversion of 'or' statments:
# True
# True
# True
# True

# %%
"Brian" == "Brian" or 100 >= 10
#True or True
# Out:
# True

# %%
nota = 7

0 <= nota <= 10
# Out:
# True

# %% [markdown]
# Se tivermos mais de duas comparações pra fazer conjunção, é melhor usarmos parênteses.
#
# Primeiro a conjunção entre parênteses é feita, e depois o resultado é usado pra avaliar a conjunção total

# %%
3 < 10 and ("Caio" == "Caio " or 50 >= 50)
# Out:
# True

# %%
3 < 10 and (False or True)
# Out:
# True

# %%
3 < 10 and True
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True
# Out:
# True

# %% [markdown]
# # Condicionais (If)
# O condicional If tem a seguinte estrutura

# %%
if condicao:
    # código a ser executado se a condição for satisfeita

# %% [markdown]
# Note que seu programa vai seguir um fluxo linha a linha e na condicional haverá um possível **desvio de fluxo**, isto é, caso a condição não seja satisfeita o código pula tudo que esta dentro do if, e o que está dentro do if? Tudo aquilo que está na **identação** do if, ou seja, está um _tab_ mais a frente que o if.

# %%
a = int(input("Digite o valor de 'a': "))
b = int(input("Digite o valor de 'b': "))

if a > b:
    print("'a' maior que 'b'")

print("Fim")
# Out:
# Digite o valor de 'a': 5
# Digite o valor de 'b': 2
# 'a' maior que 'b'
# Fim

# %% [markdown]
# ### Elif
# O _elif_ deve ser lido com **se não**, portanto ele será uma nova condição que será testada **caso a condição do if (ou outros elifs acima) NÃO seja satisfeita**, e sua estrutura é a seguinte:

# %%
if condicao:
    # codigo caso if seja satisfeito
elif condicaoElif:
    # codigo caso elif satisfeito
elif condicaoElif2:
    # codigo caso elif2 satisfeito
elif condicaoElif3:
    # codigo caso elif3 satisfeito
# Out:
#   File "<ipython-input-59-f9a791944361>", line 3
#     elif condicaoElif:
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# Note que podemos ter de 0 a N _elifs_, e seu código seguirá uma ordem de conferir as condições uma a uma até que uma seja satisfeita, seu código executa **e todo o resto do bloco de if elif será ignorado**. Note também que caso nenhuma condição seja satisfeita nada dentro do if e elifs é executado e o código "passa reto".

# %%
nota = int(input("Digite o valor de 'nota': "))

if 10 < nota:
    print("'nota' maior que 10")
elif 7 < nota:
    print("'nota' entre 7 e 10")
elif 3 < nota:
    print("'nota' entre 3 e 7")
elif 0 < nota:
    print("'nota' entre 0 e 3")
    
print("Fim")
# Out:
# Digite o valor de 'nota': 11
# 'nota' maior que 10
# Fim

# %% [markdown]
# ### Else
#
# O else deve ser lido como um **então ou caso contrário**, ele, diferente dos exemplos acima, não tem uma condiçao, ele será colocado ao fim do bloco if e será executado **quando todas as condições anteriores forem insatisfeitas**, a estrutura com else fica da seguinte maneira:

# %%
if condicao:
    # codigo caso if seja satisfeito
elif condicaoElif:
    # codigo caso elif satisfeito
else:
    # codigo caso if e elif insatisfeito
    
if condicao:
    # codigo caso if seja satisfeito
else:
    # codigo caso if insatisfeito
# Out:
#   File "<ipython-input-72-5d6b42f7434e>", line 3
#     elif condicaoElif:
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# Note que no contexto de _if else_ os _elifs_ são opcionais, portanto um bloco completo de _if_ pode possuir de 0 a N _elifs_ entre o _if_ e o _else_.

# %%
a = float(input("Digite o valor de 'a': "))

if a > 10:
    print("'a' maior que 10")
elif 7 < a:
    print("'a' entre +7 e 10")
elif 3 < a:
    print("'a' entre +3 e 7")
elif 0 < a:
    print("'a' entre +0 e 3")
else:
    print("'a' é menor ou igual a 0")
    
print("Fim")
# Out:
# Digite o valor de 'a': 5
# 'a' entre +3 e 7
# Fim

# %% [markdown]
# ### Condicional Aninhada
#
# Dentro de um _if, elif ou else_ podemos ter outros blocos de _ifs_ o que chamamos de aninhamento, isto pode ser feito para facilitar leitura de código ou mesmo para validar uma segunda condição que afeitaria pouco o código da primeira, veja o exemplo:

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))

if idade >= 18:
    habilitado = input("Você tem habilitação? (S/N): ")
    if habilitado == "S" or habilitado == "s": #also habilitado.lower() == 's'
        print("Olá,", nome, "você tem", idade, "anos e pode dirigir")
    else:
        print("Olá,", nome, "você tem", idade, "anos mas não pode dirigir")
else:
    print("Olá,", nome, "você é menor de idade, por tanto não pode dirigir.")
# Out:
# Digite seu nome: Bruno
# Digite sua idade: 26
# Você tem habilitação? (S/N): N
# Olá, Bruno você tem 26 anos mas não pode dirigir

# %% [markdown]
# ### Condicional Curta (Operador ternário)
# Operadores ternários são maneiras bem enxutas de escrever condicionais simples em apenas uma linha
# #### If Curto

# %%
a = int(input("Digite um valor para 'a': "))

if a > 10: print("'a' maior que 10")
# Out:
# Digite um valor para 'a': 11
# 'a' maior que 10

# %% [markdown]
# #### If Else Curto

# %%
a = int(input("Digite um valor para 'a': "))

if a > 10:
    print("'a' maior que 10") 
else:
    print("'a' menor ou igual a 10")
# Out:
# Digite um valor para 'a': 6
# 'a' menor ou igual a 10

# %%
a = int(input("Digite um valor para 'a': "))

# true-command if condition else false-command
print("'a' maior que 10") if a > 10 else print("'a' menor ou igual a 10")
# Out:
# Digite um valor para 'a': 6
# 'a' menor ou igual a 10

# %%
a = int(input("Digite um valor para 'a': "))

#nested inline if-else statement
print("oi") if a > 10 else (print("ola") if a > 7 else print("tchau"))
# Out:
# Digite um valor para 'a': 5
# tchau

# %%
a = int(input("Digite um valor para 'a': "))

# if a > 10:
#     y = 1
# else:
#     y = 4

y = (1 if a > 10 else 4)

# if a > 10:
#     y = True
# else:
#     y = False

y = a > 10
    
print(y)
# Out:
# Digite um valor para 'a': 5
# 4

# %% [markdown]
# # Inversão Lógica

# %%
x = 150
y = 100

# %%
not x < y
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
not(x == y and "B" != "b") == (not(x == y) or not("B" != "b"))
# Out:
# True

# %%
x != y or "B" == "b"
# Out:
# True

# %% [markdown]
# ---

# %%
not("Caio" == "Caio " or 5 <= 8)

# %%
not("Caio" == "Caio ") and not(5 <= 8)

# %%
"Caio" != "Caio " and 5 > 8

# %% [markdown]
# ---

# %%
statement1 = "João é carteiro"
statement2 = "João toca guitarra"
(statement1 == "João é carteiro") and (statement2 == "João toca guitarra")
# Out:
# True

# %%
statement3 = "João não é carteiro"
statement4 = "João não toca guitarra"
print((statement3 == "João é carteiro") and (statement2 == "João toca guitarra"))
print((statement1 == "João é carteiro") and (statement4 == "João toca guitarra"))
print((statement3 == "João é carteiro") and (statement4 == "João toca guitarra"))
print(f'''Logo é suficiente afirmar que "{statement3}" OU que "{statement4}" 
para negar que "{statement1}" E que "{statement2}", 
pois se negar uma das proposições simples não tem como as duas serem verdadeiras ao mesmo tempo, 
que é o que a proposição composta requer, logo nega-se toda a proposição composta''')
# Out:
# False
# False
# False
# Logo é suficiente afirmar que "João não é carteiro" OU que "João não toca guitarra"
# para negar que "João é carteiro" E que "João toca guitarra",
# pois se negar uma das proposições simples não tem como as duas serem verdadeiras ao mesmo tempo,
# que é o que a proposição composta requer, logo nega-se toda a proposição composta

# %% [markdown]
# ---

# %%
True and False
# Out:
# False

# %%
not(True and False)
# Out:
# True

# %%
not(True) or not(False)
# Out:
# True

# %%
False or True
# Out:
# True

# %% [markdown]
# ## Exercícios

# %% [markdown]
# **1)** Um posto está vendendo combustíveis com a seguinte tabela de descontos: <br>
#
# Álcool:<br>
#  - até 20 litros, desconto de 3% por litro
#  - acima de 20 litros, desconto de 5% por litro <br>
#
# Gasolina:<br>
#  - até 20 litros, desconto de 4% por litro
#  - acima de 20 litros, desconto de 6% por litro.
#
# Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da gasolina é 2,50 reais o preço do litro do álcool é 1,90 reais.

# %%
gas_type_code = input('Qual o tipo de combustível (G: gasolina; A: álcool)? ')
liters = float(input('Qual a quantidade de litros vendidos? ')) 


UNIT_PRICE_GASOLINE = 2.5
UNIT_PRICE_ALCOHOL = 1.9


if gas_type_code.lower() == 'g':
  valor = liters*UNIT_PRICE_GASOLINE
  valor *= (0.96 if liters <= 20 else 0.94)
  # if (liters <= 20):
  #   valor *= 0.97
  # else:
  #   valor *= 0.95
elif gas_type_code.lower() == 'a':
  valor = liters*UNIT_PRICE_ALCOHOL
  valor *= (0.97 if liters <= 20 else 0.95)
else:
  print('Tipo de combustível inválido.')

print(f'O valor a ser pago é de R${valor}')
# Out:
# Qual o tipo de combustível (G: gasolina; A: álcool)? a
# Qual a quantidade de litros vendidos? 30
# O valor a ser pago é de R$54.15

# %% [markdown]
# **2)** Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
#
# - "Telefonou para a vítima?"
# - "Esteve no local do crime?"
# - "Mora perto da vítima?"
# - "Devia para a vítima?"
# - "Já trabalhou com a vítima?"
#
# O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".

# %%
count_positive = 0
count_positive += 1 if(input('Telefonou para a vítima (S/N)? ').lower()=='s') else 0
count_positive += 1 if(input('Esteve no local do crime (S/N)? ').lower()=='s') else 0
count_positive += 1 if(input('Mora perto da vítima (S/N)? ').lower()=='s') else 0
count_positive += 1 if(input('Devia para a vítima (S/N)? ').lower()=='s') else 0
count_positive += 1 if(input('Já trabalhou com a vítima (S/N)? ').lower()=='s') else 0


if(count_positive==5):
  classification = 'Assassino'
elif(count_positive > 2):
  classification = 'Cúmplice'
elif(count_positive == 2):
  classification = 'Suspeita'
else:
  classification = 'Inocente'
# classification = 'Assassino' if count_positive == 5 else ('Cúmplice' if count_positive > 2 else('Supeita' if count_positive == 2 else 'Inocente'))

print(f'Essa pessoa é {classification}')
# Out:
# Telefonou para a vítima (S/N)? s
# Esteve no local do crime (S/N)? s
# Mora perto da vítima (S/N)? s
# Devia para a vítima (S/N)? n
# Já trabalhou com a vítima (S/N)? n
# Essa pessoa é Cúmplice

# %% [markdown]
# **3)** Faça um Programa que leia um número inteiro menor que 1000 e imprima a quantidade de centenas, dezenas e unidades do mesmo. Observando os termos no plural a colocação do "e", da vírgula entre outros. Exemplo:
#
# 326 = 3 centenas, 2 dezenas e 6 unidades <br>
# 12 = 1 dezena e 2 unidades

# %%
number = int(input('Digite um número inteiro: '))

# desmembrar o numero
centenas = number//100
number %= 100
dezenas = number//10
number %= 10
unidades = number

resposta = ""
resposta += f"{centenas} centena" if centenas == 1 else(f"{centenas} centenas" if centenas > 1 else "")
resposta += f" e " if (centenas > 0 and dezenas > 0 and unidades == 0) else (', ' if (centenas > 0 and dezenas > 0 and unidades > 0) else "")
resposta += f"{dezenas} dezena" if dezenas == 1 else(f"{dezenas} dezenas" if dezenas > 1 else "")
resposta += f" e " if ((centenas != 0 or dezenas != 0) and unidades > 0) else ''
resposta += f"{unidades} unidade " if unidades == 1 else(f"{unidades} unidades" if unidades > 1 else "")

print(resposta)
# Out:
# Digite um número inteiro: 123
# 1 centena, 2 dezenas e 3 unidades

# %% [markdown]
# **4)** Faça um programa que calcule as raízes de uma equação do segundo grau, na forma:
#
# $ax^{2} + bx + c$
#
# O programa deverá pedir os valores de a, b e c, informando ao usuário nas seguintes situações:
# Se o usuário informar o valor de A igual a zero, a equação não é do segundo grau e o programa não deve fazer pedir os demais valores, sendo encerrado;
# Se o delta calculado for negativo, a equação não possui raizes reais. Informe ao usuário e encerre o programa;
# Se o delta calculado for igual a zero a equação possui apenas uma raiz real; informe-a ao usuário;
# Se o delta for positivo, a equação possui duas raiz reais; informe-as ao usuário;

# %%
print("Cálculo de ráizes de equações de segundo grau na forma a*x^2+b*x+c")
a = float(input("Informe o valor do coeficiente a: "))

if a != 0:
  b = float(input("Informe o valor do coeficiente b: "))
  c = float(input("Informe o valor do coeficiente c: "))
  
  print(f'A equação tem a forma: {a:.2f}x^2+{b:.2f}x+{c:.2f}')
  
  delta = b**2.0 - 4.0 * a * c
  if delta < 0:
    print(f'A equação tem duas raízes complexas distintas: {-b/(2.0*a):.2f}+{((-1.0)*delta)**0.5/(2.0*a):.2f}i e {-b/(2.0*a):.2f}-{((-1.0)*delta)**0.5/(2.0*a):.2f}i')
  elif delta == 0:
    print(f'A equação tem duas raízes reais e iguais: {-b/(2.0*a):.2f}')
  else:
    print(f'A equação tem duas raízes reais distintas: {(-b+delta**0.5)/(2.0*a):.2f} e {(-b-delta**0.5)/(2.0*a):.2f}')
else:
  print('Como o coeficiente a=0, a equação informada não será de segundo grau.')
# Out:
# Cálculo de ráizes de equações de segundo grau na forma a*x^2+b*x+c
# Informe o valor do coeficiente a: 1
# Informe o valor do coeficiente b: 2
# Informe o valor do coeficiente c: 1
# A equação tem a forma: 1.00x^2+2.00x+1.00
# A equação tem duas raízes reais e iguais: ±1.00

# %% [markdown]
# **5)** Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário o valor do saque e depois informar quantas notas de cada valor serão fornecidas, considerando o valor mínimo de notas possíveis. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais.

# %%
valor_saque = int(input('Digite um valor monetário: R$'))

# desmembrar o numero
nota_100 = valor_saque//100
valor_saque %= 100
nota_50 = valor_saque//50
valor_saque %= 50
nota_10 = valor_saque//10
valor_saque %= 10
nota_5 = valor_saque//5
valor_saque %= 5
nota_1 = valor_saque//1
valor_saque %= 1


print(f'{nota_100} notas(s) de 100, {nota_50} nota(s) de 50, {nota_10} nota(s) de 10, {nota_5} nota(s) de 5, {nota_1} nota(s) de 1.')
# Out:
# Digite um valor monetário: R$467
# 4 notas(s) de 100, 1 nota(s) de 50, 1 nota(s) de 10, 1 nota(s) de 5, 2 nota(s) de 1.

# %% [markdown]
# **6)** Faça um Programa que peça os 3 lados de um triângulo. O programa deverá informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo, se o mesmo é: equilátero, isósceles ou escaleno.
#
# Dicas:
# - Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# - Triângulo Equilátero: três lados iguais;
# - Triângulo Isósceles: quaisquer dois lados iguais;
# - Triângulo Escaleno: três lados diferentes;

# %%
lado1 = float(input('Digite o comprimento do primeiro lado: '))
lado2 = float(input('Digite o comprimento do segundo lado: '))
lado3 = float(input('Digite o comprimento do terceiro lado: '))

#deixe a condição mais simples antes!
if not(lado1+lado2 > lado3 and lado3+lado1 > lado2 and lado2+lado3 > lado1):
  print('Os comprimento dos lados não formam um triângulo pois a soma dos comprimentos de dois lados resultou menor que o comprimento de outro lado.')
else:
  resposta = 'É um triângulo '
  if(lado1 == lado2 == lado3):
    resposta += 'equilátero.'
  elif (lado1==lado2 or lado1 == lado3 or lado2 == lado3):
    resposta += 'isósceles.'
  else:
    resposta += 'escaleno'
  print(resposta)

# %% [markdown]
# **7)** Faça um programa que peça a idade do usuário e imprima se ele é maior ou menor de 18 anos.

# %%
age = int(input('Digite sua idade: '))

print('Você tem mais de 18 anos de idade.' if age > 18 else('Você tem 18 anos de idade.' if age == 18 else 'Você tem menos de 18 anos de idade.') )
# Out:
# Digite sua idade: 26
# Você tem mais de 18 anos de idade.

# %% [markdown]
# **8)** Faça um programa que peça um número e mostre se ele é positivo ou negativo.

# %%
number = float(input('Digite um número: '))

print('O número é positivo.' if number > 0 else('O número não é nem positivo nem negativo.' if number == 0 else 'O número é negativo.'))
# Out:
# Digite um número: 0
# O número não é nem positivo nem negativo.

# %% [markdown]
# **9)** Faça um programa que peça dois números e mostre o maior deles.

# %%
print('Comparando dois números reais')
number1 = float(input('Digite um número: '))
number2 = float(input('Digite outro número: '))

print(f'{number1} é maior que {number2}.' if number1 > number2 else(f'{number1} é menor que {number2}.' if number1 < number2 else f'Os números são iguais.'))
# Out:
# Digite um número: 58
# Digite outro número: 77
# 58.0 é menor que 77.0.

# %% [markdown]
# **10)** Faça um programa que leia a validade das informações:
#
# - Idade: entre 0 e 150;
#
# - Salário: maior que 0;
#
# - Sexo: M, F ou Outro;
#
# O programa deve imprimir uma mensagem de erro para cada informação inválida.

# %%
age = int(input('Digite a sua idade: '))
if not(0<=age<=150): print(f'Entrada de idade inválida. Por favor, digite um idade entre 0 e 150 anos.')

salary = int(input('Digite o seu salário: '))
if salary<=0: print(f'Entrada de salário inválida. Por favor, digite valor maior que 0.')

sex = input('Qual o seu sexo (F/M/Outro)')
if sex not in ['M', 'F', 'Outro']: print(f'Entrada de sexo inválida. Por favor, digite valor maior que 0.')
# Out:
# Digite a sua idade: 25
# Digite o seu salário: 25
# Qual o seu sexo (F/M/Outro)M

# %% [markdown]
# **11)** Faça um programa que leia dois números e informe o maior deles.

# %%
print('Maior entre dois número')
number1 = float(input('Digite um número: '))
number2 = float(input('Digite outro número: '))

print(f'{number1} é o maior.' if number1 > number2 else(f'{number2} é o maior.' if number1 < number2 else f'Os números são iguais.'))

# %% [markdown]
# **12)** Faça um código que leia um número e informe se ele é par ou ímpar.

# %%
number = float(input('Digite um número: '))

print(f'{number} é par.' if number%2 == 0 else f'{number} é ímpar.')
# Out:
# Digite um número: 25
# 25.0 é ímpar.

# %% [markdown]
# **12)** Faça um programa que receba 3 notas de prova de um aluno, calcule a média e diga se ele foi aprovado ou reprovado. A média para aprovação é de pelo menos 6 (aprovado se média maior ou igual a 6).

# %%
grade1 = float(input('Digite a nota da primeira prova do aluno: '))
grade2 = float(input('Digite a nota da segunda prova: '))
grade3 = float(input('Digite a nota da terceira prova: '))

average = (grade1+grade2+grade3)/3

print(f'O aluno foi aprovado.' if average >= 6.0 else f'O aluno foi reprovado.')

# %% [markdown]
# 14) Uma empresa irá aplicar um reajuste nos salários de seus funcionários de acordo com as seguintes regras:
#
# - Salário até R$2800,00 (incluindo): aumento de 20%;
#
# - Salários entre R 2800,00 e R$7000,00: aumento de 15%;
#
# - Salários entre R 7000,00 e R$15000,00: aumento de 10%;
#
# - Salários de R$15000,00 em diante: aumento de 5%.
#
# Dado o salário de um funcionário, informe: o salário antes do reajuste; o percentual de aumento aplicado; o valor do aumento e o novo salário.

# %%
salary = float(input('Entre com o valor do salário do funcionário: R$'))

if salary <= 2800.0:
  raise_percent = 20
elif salary <= 7000.0:
  raise_percent = 15
elif salary <= 15000.0:
  raise_percent = 10
else:
  raise_percent = 5

new_salary = salary * (1+raise_percent/100)

print(f'O salário antes do reajuste era R${salary:.2f}.\nApós o aumento de {raise_percent}%, o novo salário será de R${new_salary:.2f}.')
# Out:
# Entre com o valor do salário do funcionário: R$1500
# O salário antes do reajuste era 1500.00.
# Após o aumento de 20%, o novo salário será de 1800.00.

# %%
\
